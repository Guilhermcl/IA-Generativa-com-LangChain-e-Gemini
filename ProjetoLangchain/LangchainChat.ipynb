# %%
import yaml
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage

# %%
with open('Config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)

# %%
gemini = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key='AIzaSyCnoRPBWtlLyxQGWe_ewVVSyPpVn8-4Roo',
    temperature=0.7
    )

# %%
messages = [
    {"role": "system", "content": "Voce é um assistente que fornece provérbios populares."},
    {"role": "user", "content": "Conte um provérbio popular!"}
]

# %%
response = gemini.invoke(messages)

# %%
print(response.content)
# Out:
# Claro! Aqui vai um provérbio popular:
#
# "Mais vale um pássaro na mão do que dois voando."
#
# **Significado:** É melhor se contentar com o que você já tem e é certo, do que arriscar perder tudo ao tentar conseguir algo maior ou incerto.
